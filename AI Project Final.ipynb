# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("data.csv")

# %%
data.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
data.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
data.corr()
# Out:
#                                age   anaemia  creatinine_phosphokinase  \
# age                       1.000000  0.088006                 -0.081584
# anaemia                   0.088006  1.000000                 -0.190741
# creatinine_phosphokinase -0.081584 -0.190741                  1.000000
# diabetes                 -0.101012 -0.012729                 -0.009639
# ejection_fraction         0.060098  0.031557                 -0.044080
# high_blood_pressure       0.093289  0.038182                 -0.070590
# platelets                -0.052354 -0.043786                  0.024463
# serum_creatinine          0.159187  0.052174                 -0.016408
# serum_sodium             -0.045966  0.041882                  0.059550
# sex                       0.065430 -0.094769                  0.079791
# smoking                   0.018668 -0.107290                  0.002421
# time                     -0.224068 -0.141414                 -0.009346
# ...

# %%
data.isnull().value_counts()
# Out:
# age    anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex    smoking  time   DEATH_EVENT
# False  False    False                     False     False              False                False      False             False         False  False    False  False          299
# dtype: int64

# %%
data.isna().sum(axis=0)
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
plt.figure(figsize=(11,11))
sns.heatmap(data.corr(),annot=True,linewidths=1,cmap='Reds')
plt.show()

# %%
sns.pairplot(data)

# %%
plt.boxplot(data['age'])
plt.show()

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(5,5))
sns.boxplot(y="age",x="DEATH_EVENT",data=data)
plt.show()

# %%
cols = ['creatinine_phosphokinase','ejection_fraction', 'platelets','serum_creatinine', 'serum_sodium']

for i in cols:
    sns.set_style("whitegrid")
    plt.figure(figsize=(5,5))
    sns.boxplot(y=i,data=data)
    plt.show()

# %%
from pandas import DataFrame


def removeOutliers(df:DataFrame,col):
    Q1= df[col].quantile(0.25)
    Q2 = df[col].quantile(0.75)
    IQR = Q2 - Q1
    lower_limit = Q1 - (1.5)*IQR
    upper_limit = Q2 + (1.5)*IQR
    lower_outliers = df[col] < lower_limit
    upper_outliers = df[col] > upper_limit
    return [lower_outliers,upper_outliers]

# %%
old_data = data.copy()
for i in cols:
    lo,uo = removeOutliers(data,i)
    data = data[~(lo | uo)]

# %%
data.shape
# Out:
# (224, 13)

# %%
cols = ['creatinine_phosphokinase','ejection_fraction', 'platelets','serum_creatinine', 'serum_sodium']

for i in cols:
    sns.set_style("whitegrid")
    plt.figure(figsize=(5,5))
    sns.boxplot(y=i,data=data)
    plt.show()

# %%
sns.countplot(x=data['DEATH_EVENT'])
plt.show()

# %%
sns.histplot(data=data,x="age",kde=True,hue="DEATH_EVENT",multiple='stack')
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.histplot(data=data,x="serum_creatinine",kde=True,hue="DEATH_EVENT",multiple='stack')
plt.show()

# %%
sns.barplot(data=data,y="serum_creatinine",x="DEATH_EVENT")
# Out:
# <AxesSubplot:xlabel='DEATH_EVENT', ylabel='serum_creatinine'>

# %%
sns.scatterplot(data=data,y="serum_creatinine",x="DEATH_EVENT")
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop(labels="DEATH_EVENT",axis=1)
y = data['DEATH_EVENT']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression()

# %%
lm = logreg.fit(X_train,y_train)

# %%
lm.score(X_test,y_test)
# Out:
# 0.8235294117647058

# %%
# Try with normalized values
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
new_data = data.copy()

# %%
new_data.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0 75.00        0                       582         0                 20
# 2 65.00        0                       146         0                 20
# 3 50.00        1                       111         0                 20
# 5 90.00        1                        47         0                 40
# 6 75.00        1                       246         0                 15
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00              1.90           130    1
# 2                    0  162000.00              1.30           129    1
# 3                    0  210000.00              1.90           137    1
# 5                    1  204000.00              2.10           132    1
# 6                    0  127000.00              1.20           137    1
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 2        1     7            1
# ...

# %%
new_data[['age','creatinine_phosphokinase','ejection_fraction','platelets','serum_creatinine','time','serum_sodium']] = scaler.fit_transform(data[['age','creatinine_phosphokinase','ejection_fraction','platelets','serum_creatinine','time','serum_sodium']])

# %%
new_data.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  1.19        0                      0.88         0              -1.56
# 2  0.35        0                     -0.68         0              -1.56
# 3 -0.91        1                     -0.81         0              -1.56
# 5  2.45        1                     -1.04         0               0.16
# 6  1.19        1                     -0.33         0              -1.98
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1       0.14              2.36         -1.85    1
# 2                    0      -1.40              0.52         -2.12    1
# 3                    0      -0.68              2.36         -0.01    1
# 5                    1      -0.77              2.97         -1.33    1
# 6                    0      -1.92              0.22         -0.01    1
#
#    smoking  time  DEATH_EVENT
# 0        0 -1.68            1
# 2        1 -1.64            1
# ...

# %%
X = new_data.drop(labels="DEATH_EVENT",axis=1)
y = new_data['DEATH_EVENT']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.7,test_size=0.3,random_state=42)

# %%
X_train.describe()
# Out:
#          age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# count 156.00   156.00                    156.00    156.00             156.00
# mean   -0.00     0.45                      0.05      0.42              -0.11
# std     1.00     0.50                      1.01      0.50               1.00
# min    -1.75     0.00                     -1.10      0.00              -2.07
# 25%    -0.91     0.00                     -0.80      0.00              -0.70
# 50%    -0.07     0.00                     -0.35      0.00              -0.27
# 75%     0.77     1.00                      0.88      1.00               0.58
# max     2.78     1.00                      3.10      1.00               1.87
#
#        high_blood_pressure  platelets  serum_creatinine  serum_sodium    sex  \
# count               156.00     156.00            156.00        156.00 156.00
# mean                  0.39       0.07              0.01         -0.05   0.66
# ...

# %%
# X_train[['age','creatinine_phosphokinase','ejection_fraction','platelets','serum_creatinine','time']] = scaler.fit_transform(X_train[['age','creatinine_phosphokinase','ejection_fraction','platelets','serum_creatinine','time']])

# %%
norm_logreg = LogisticRegression()
nor_lm = norm_logreg.fit(X_test,y_test)

# %%
nor_lm.score(X_test,y_test)
# Out:
# 0.9264705882352942

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score,ConfusionMatrixDisplay

# %%
print(classification_report(y_test,nor_lm.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95        52
#            1       0.87      0.81      0.84        16
#
#     accuracy                           0.93        68
#    macro avg       0.91      0.89      0.90        68
# weighted avg       0.93      0.93      0.93        68

# %%
accuracy_score(y_test,nor_lm.predict(X_test),normalize=True)
# Out:
# 0.9264705882352942

# %%
cm = confusion_matrix(y_test,nor_lm.predict(X_test),labels=[0,1])
print(cm)
# Out:
# [[50  2]
#  [ 3 13]]

# %%
cmd = ConfusionMatrixDisplay(cm,display_labels=[0,1])

# %%
plt.figure(figsize=(12,12))
# plt.grid(False)
sns.reset_orig()
cmd.plot()
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# %%
dt = DecisionTreeClassifier(random_state=42)

# %%
config = {
    "max_depth": [2,3,4,5,7,9,10,12,15,17,20],
    "min_samples_leaf": [1,2,3,4,5,7,8,9,10,20,50,100,500]
}

# %%
gscv = GridSearchCV(dt,config,n_jobs=-1,scoring='accuracy',verbose=2,cv=5)

# %%
gscv.fit(X_train,y_train,)
# Out:
# Fitting 5 folds for each of 143 candidates, totalling 715 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [2, 3, 4, 5, 7, 9, 10, 12, 15, 17, 20],
#                          'min_samples_leaf': [1, 2, 3, 4, 5, 7, 8, 9, 10, 20,
#                                               50, 100, 500]},
#              scoring='accuracy', verbose=2)

# %%
dt_best = gscv.best_estimator_
dt_best
# Out:
# DecisionTreeClassifier(max_depth=2, min_samples_leaf=20, random_state=42)

# %%
gscv.best_score_
# Out:
# 0.8528225806451614

# %%
print(classification_report(y_test,dt_best.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.92      0.90        52
#            1       0.69      0.56      0.62        16
#
#     accuracy                           0.84        68
#    macro avg       0.78      0.74      0.76        68
# weighted avg       0.83      0.84      0.83        68

# %%
accuracy_score(y_train,dt_best.predict(X_train))
# Out:
# 0.8846153846153846

# %%
    print("Train Accuracy :", accuracy_score(y_train, dt_best.predict(X_train)))
    print("Train Confusion Matrix:")
    print(confusion_matrix(y_train, dt_best.predict(X_train)))
    print("-"*50)
    print("Test Accuracy :", accuracy_score(y_test, dt_best.predict(X_test)))
    print("Test Confusion Matrix:")
    print(confusion_matrix(y_test, dt_best.predict(X_test)))
# Out:
# Train Accuracy : 0.8846153846153846
# Train Confusion Matrix:
# [[108   3]
#  [ 15  30]]
# --------------------------------------------------
# Test Accuracy : 0.8382352941176471
# Test Confusion Matrix:
# [[48  4]
#  [ 7  9]]

# %%
cmd = ConfusionMatrixDisplay(confusion_matrix(y_test, dt_best.predict(X_test)))

plt.figure(figsize=(12,12))
# plt.grid(False)
sns.reset_orig()
cmd.plot()
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()

# %%
gnb.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
def displayScores(model):
    print("Train Accuracy :", accuracy_score(y_train, model.predict(X_train)))
    print("Train Confusion Matrix:")
    print(confusion_matrix(y_train, model.predict(X_train)))
    print("-"*50)
    print("Test Accuracy :", accuracy_score(y_test, model.predict(X_test)))
    print("Test Confusion Matrix:")
    print(confusion_matrix(y_test, model.predict(X_test)))

# %%
displayScores(gnb)
# Out:
# Train Accuracy : 0.8525641025641025
# Train Confusion Matrix:
# [[101  10]
#  [ 13  32]]
# --------------------------------------------------
# Test Accuracy : 0.8088235294117647
# Test Confusion Matrix:
# [[48  4]
#  [ 9  7]]

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
kn = KNeighborsClassifier()

# %%
kn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
displayScores(kn)
# Out:
# Train Accuracy : 0.8461538461538461
# Train Confusion Matrix:
# [[107   4]
#  [ 20  25]]
# --------------------------------------------------
# Test Accuracy : 0.7647058823529411
# Test Confusion Matrix:
# [[49  3]
#  [13  3]]

# %%
from lazypredict.Supervised import LazyClassifier

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None,random_state=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████| 29/29 [00:01<00:00, 25.16it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.84               0.79     0.79      0.84
# AdaBoostClassifier                 0.82               0.75     0.75      0.82
# BaggingClassifier                  0.84               0.74     0.74      0.83
# LGBMClassifier                     0.82               0.73     0.73      0.82
# RandomForestClassifier             0.82               0.71     0.71      0.81
# CalibratedClassifierCV             0.84               0.70     0.70      0.82
# SGDClassifier                      0.76               0.69     0.69      0.77
# LinearSVC                          0.81               0.68     0.68      0.80
# LogisticRegression                 0.81               0.68     0.68      0.80
# GaussianNB                         0.81               0.68     0.68      0.80
# ...
